# %% [markdown]
# Data Understanding

# %% [markdown]
# 1.Load the dataset into pandas

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\IT\Desktop\Data Analysis\AnalystLab Africa Internship\OnlineRetail.csv\OnlineRetail_Original.csv",encoding='latin1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# 2. Display the first few rows.

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# 3. Identify:
# - Number of rows and columns
# - Data types of all columns
# - Numerical features
# - Categorical features
# - Possible unique identifiers (primary keys)

# %%
#Number of rows and columns
df.shape
# Out:
# (541909, 8)

# %%
# Data types of all columns
df.dtypes
# Out:
# InvoiceNo          str
# StockCode          str
# Description        str
# Quantity         int64
# InvoiceDate        str
# UnitPrice      float64
# CustomerID     float64
# Country            str
# dtype: object

# %%
# Numerical features
df.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['Quantity', 'UnitPrice', 'CustomerID'], dtype='str')

# %%
#Categorical features
df.select_dtypes(include=['object','string']).columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate', 'Country'], dtype='str')

# %%
#Possible unique identifiers (primary keys)
df['StockCode'].nunique()
# Out:
# 4372

# %%
df['InvoiceNo'].nunique()
# Out:
# 25900

# %%
df['CustomerID'].nunique()
# Out:
# 4372

# %%
#Check if any primary key is there in dataset
df['InvoiceNo'].is_unique
df['StockCode'].is_unique
df['CustomerID'].is_unique
# Out:
# False

# %%
len(df)
# Out:
# 541909

# %% [markdown]
# 4. Briefly describe what the dataset contains.
#
#    This dataset contains online retail transaction records including invoice number,
#    product code, product description, quantity purchased, invoice date,
#    unit price, customer ID and country.
